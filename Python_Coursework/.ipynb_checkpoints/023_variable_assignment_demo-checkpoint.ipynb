# %%
price = 5

# %%
price
# Out:
# 5

# %%
print(price + 1)
# Out:
# 6

# %%
tax = 2

print(price + tax)
# Out:
# 7

# %%
product_name = 'skis'

print(product_name)
# Out:
# skis

# %%
price_list = [2.50, 4.99, 10, None, 'Discount']

price_list_type = type(price_list)

price_list_type
# Out:
# list
